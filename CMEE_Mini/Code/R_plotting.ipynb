# ⋮  ⋮
# 60 warm
# 61 warm
# 62 cold
# 63 cold
# 64 cold
# 65 cold
# 66 cold
# 67 cold
# 68 cold
# 69 cold
# 70 cold
# 71 cold
# 72 cold
# 73 cold
# 74 cold
# 75 cold
# 76 cold
# 77 cold
# 78 cold
# 79 cold
# 80 cold
# 81 cold
# 82 cold
# 83 cold
# 84 cold
# 85 cold
# 86 cold
# 87 cold
# 88 cold
# 89 cold

# %%
df2 = read.csv("../Data/Respiration_data.csv")
df2
# Out:
#     X   stream stream_temp exp_temp mass      resp       Exp_Temp_K log_resp
# 1    0  11     5.6          5        3.014683 0.01043837 278.15     -4.56226703
# 2    1  11     5.6          5        3.014683 0.01600242 278.15     -4.13501507
# 3    2  11     5.6          5       11.716683 0.03920282 278.15     -3.23900670
# 4    3  11     5.6          5       11.716683 0.04246072 278.15     -3.15917594
# 5    4  11     5.6          5       13.338753 0.04268669 278.15     -3.15386809
# 6    5  11     5.6          5       13.338753 0.07688335 278.15     -2.56546598
# 7    6  11     5.6          5       23.529307 0.36681050 278.15     -1.00290992
# 8    7  11     5.6         10       16.986706 0.19887359 283.15     -1.61508590
# 9    8  11     5.6         10       21.959874 0.14387114 283.15     -1.93883725
# 10   9  11     5.6         10       29.566405 0.22769918 283.15     -1.47972990
# 11  10  11     5.6         10       29.566405 0.23105250 283.15     -1.46511030
# 12  11  11     5.6         10       33.709745 0.45971523 283.15     -0.77714804
# 13  12  11     5.6         15       12.783466 0.15457619 288.15     -1.86706820
# 14  13  11     5.6         15       12.783466 0.16523093 288.15     -1.80041123
# 15  14  11     5.6         15       29.566405 0.50273676 288.15     -0.68768859
# 16  15  11     5.6         15       45.537347 0.06858780 288.15     -2.67964060
# 17  16  11     5.6         15       55.871631 0.96879470 288.15     -0.03170256
# 18  17  11     5.6         20        1.857024 0.04481100 293.15     -3.10530163
# 19  18  11     5.6         20       16.986706 0.36570369 293.15     -1.00593187
# 20  19  11     5.6         20       19.730960 0.56365491 293.15     -0.57331308
# 21  20  11     5.6         20       21.200350 0.55602540 293.15     -0.58694131
# 22  21  11     5.6         20       25.166879 0.62048764 293.15     -0.47724959
# 23  22  11     5.6         20       34.416539 0.09087600 293.15     -2.39825934
# 24  23  11     5.6         25        4.924184 0.35016588 298.15     -1.04934831
# 25  24  11     5.6         25        5.917513 0.30810586 298.15     -1.17731187
# 26  25  11     5.6         25        7.217396 0.33369600 298.15     -1.09752488
# 27  26  11     5.6         25       10.223631 0.47680034 298.15     -0.74065744
# 28  27  11     5.6         25       10.707242 0.37502563 298.15     -0.98076091
# 29  28  11     5.6         25       11.716683 0.55451600 298.15     -0.58965962
# 30  29  11     5.6         25       12.783466 0.58372629 298.15     -0.53832308
# ⋮   ⋮   ⋮      ⋮           ⋮        ⋮         ⋮          ⋮          ⋮
# 500 499 9      9.6         35       12.296237 0.64763763 308.15     -0.43442395
# 501 500 9      9.6         35       12.565462 0.41963239 308.15     -0.86837621
# 502 501 9      9.6         35       14.553223 1.10155426 308.15      0.09672215
# 503 502 9      9.6         35       17.581900 1.11393648 308.15      0.10790012
# 525 0.012674172 3.451101   36.47500 -3.321714     2.5395662 0.03609090
# 526 0.013114871 3.451101   36.47500 -3.261298     2.5737468 0.03833859
# 527 0.014792071 3.451101   36.47500 -3.363088     2.6940913 0.03462816
# 528 0.016276523 3.451101   36.47500 -3.545169     2.7897238 0.02886374
# 529 0.016921361 3.451101   36.47500 -3.481034     2.8285768 0.03077558

# %%
legends2 = c("B0 = 0.03\n Ea = 0.99\n  Eh = 1.8\n Tpk =25","B0 = 0.03\n Ea = 0.96\n  Eh = 2.3\n  Tpk = 29",
             "B0 = 0.01\n Ea = 0.89\n  Eh = 2.2\n Tpk = 34","B0 = 0.02\n Ea = 0.60\n  Eh = 4.1\n Tpk = 37",
             "B0 = 0.015\n Ea = 0.88\n  Eh = 2.1\n  Tpk = 31","B0 = 0.03\n Ea = 0.99\n  Eh = 2.2\n  Tpk = 28",
             "B0 = 0.02\n Ea = 0.99\n  Eh = 2.2\n  Tpk = 32")
legend = data.frame(x = rep(10,7), y = rep(0.2,7), stream_temp = c(5.6,8.1,9.6, 13.2,13.9,14.4,19.3), legends = legends2)

# %%
schoolfield5 = function(x) (0.029 * exp(((-0.99)/k) * (1/(x +273.15) - 1/283.15))/
   (1 + exp((1.8/k) * (1/298 - (1/(x + 273.15))))))
schoolfield8 = function(x) (0.026 * exp(((-0.96)/k) * (1/(x + 273.15) - 1/283.15))/
    (1 + exp((2.3/k) * (1/302 - (1/(x + 273.15))))))
schoolfield9 = function(x) (0.013 * exp((-0.89/k) * (1/(x + 273.15) - 1/283.15)))/
    (1 + exp((2.2/k) * (1/307 - 1/(x + 273.15))))
schoolfield132 = function(x) (0.018 * exp((-0.60/k) * (1/(x + 273.15) - 1/283.15)))/
    (1 + exp((4.1/k) * (1/310 - 1/(x + 273.15))))
schoolfield139 = function(x) (0.015 * exp((-0.88/k) * (1/(x + 273.15) - 1/283.15)))/
    (1 + exp((2.1/k) * (1/304 - 1/(x + 273.15))))    
schoolfield14 = function(x) (0.026 * exp((-0.99/k) * (1/(x + 273.15) - 1/283.15)))/
    (1 + exp((2.2/k) * (1/301 - 1/(x + 273.15))))    
schoolfield19 = function(x) (0.021* exp((-0.99/k) * (1/(x + 273.15) - 1/283.15)))/
    (1 + exp((2.2/k) * (1/305 - 1/(x + 273.15))))    
    
resp_full_plot = ggplot(df2, aes(x =  exp_temp, y = mass_resp, color = stream_temp)) + geom_point() + facet_wrap(~stream_temp) + 
    ylab(expression(paste("Mean Corrected Oxygen Consumption (",mu,"m/h)"))) + 
    xlab(expression(paste("Experimental Temperature (", ~degree ~C,")"))) +  
    stat_function(dat = subset(df2, stream_temp == 13.2), fun = schoolfield132) + stat_function(dat = subset(df2, stream_temp == 5.6), fun = schoolfield5) + 
    stat_function(dat = subset(df2, stream_temp == 8.1), fun = schoolfield8) + stat_function(dat = subset(df2, stream_temp == 9.6), fun = schoolfield9) + 
    stat_function(dat = subset(df2, stream_temp == 13.9), fun = schoolfield139) + stat_function(dat = subset(df2, stream_temp == 14.4), fun = schoolfield14) + 
    stat_function(dat = subset(df2, stream_temp == 19.3), fun = schoolfield19) +
    theme(legend.title = element_text(face="bold"))+
    scale_color_continuous(name=(expression(paste("Acclimation Temperature (", ~degree ~C,")")))) +
    geom_text(aes(x, y, label=legends, group=NULL), size = 2, data=legend)
resp_full_plot

ggsave("../Results/Schoolfield_plots.eps")
    
school_lm = lm(mass_resp~exp_temp*stream_temp,data = df2)
summary(school_lm)
anova(school_lm)
# Out:
# Saving 6.67 x 6.67 in image
# Call:
# lm(formula = mass_resp ~ exp_temp * stream_temp, data = df2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.08834 -0.02734 -0.01282  0.02354  0.17843
#
# Coefficients:
#                       Estimate Std. Error t value Pr(>|t|)
# (Intercept)          2.035e-02  1.498e-02   1.359  0.17485
# exp_temp             1.470e-03  5.071e-04   2.900  0.00389 **
# stream_temp          2.104e-04  1.170e-03   0.180  0.85735
# exp_temp:stream_temp 8.049e-06  3.988e-05   0.202  0.84010
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.04742 on 525 degrees of freedom
# Multiple R-squared:  0.1428,	Adjusted R-squared:  0.1379
# F-statistic: 29.14 on 3 and 525 DF,  p-value: < 2.2e-16
#                      Df  Sum Sq       Mean Sq      F value     Pr(>F)
# exp_temp               1 1.947834e-01 1.947834e-01 86.61678169 3.566229e-19
# stream_temp            1 1.728033e-03 1.728033e-03  0.76842603 3.811053e-01
# exp_temp:stream_temp   1 9.163264e-05 9.163264e-05  0.04074744 8.401044e-01
# Residuals            525 1.180617e+00 2.248795e-03          NA           NA
# plot without title

# %%
legends = c("a = -9.1e-07\nb = -1.7e-04\nc = 0.0115\nd = -0.066",
            "a = -8.33e-06\nb = 3.13e-04\nc = 0.0033\nd = -0.024",
          "a = -1.27e-05\nb = 7.9e-04\nc = -0.011\nd = 0.0481",
          "a = -1.275e-05\nb = 8e-04\nc = -0.0111\nd = 0.059",
            "a = -1.1016e-05\nb = 6e-04\nc = -0.0071\nd = 0.0302",
          "a = -6.96e-06\nb = 1.6e-04\nc = 0.0077\nd = -0.062",
          "a = -1.13e-05\nb = 6e-04\nc = -0.0027\nd = -0.002")



legend = data.frame(x = rep(13,7), y = rep(0.2,7), stream_temp = c(5.6,8.1,9.6, 13.2,13.9,14.4,19.3), legends = legends)

cubic_132 = function(x) -1.275e-05*(x^3) + (0.0008*x^2) - 
                    (0.0111*x) + 0.059
cubic_5 = function(x) -9.113e-07*(x^3) - 1.7e-04*(x^2) + 
                    (0.0115*x) - 0.066
cubic_8 = function(x) - 8.33e-06*(x^3) + 0.000313*(x^2) +
                    (0.0033*x) - 0.024
cubic_9 = function(x) - 1.27e-05*(x^3) + 0.00079*(x^2) -
                    (0.011*x) + 0.0481
cubic_139 = function(x) -1.1016e-05*(x^3) + 0.000637*(x^2) - 
                    (0.0071*x) + 0.03015
cubic_14 = function(x) -6.96e-06*(x^3) + 0.00016*(x^2) + 
                    (0.0077*x) - 0.062
cubic_193 = function(x) -1.13e-05*(x^3) + 0.0006*(x^2) -
                    (0.0027*x) - 0.002
resp_full_plot2 = ggplot(df2, aes(x =  exp_temp, y = mass_resp, color = stream_temp)) + geom_point() + facet_wrap(~stream_temp) + 
    stat_function(dat = subset(df2, stream_temp == 13.2), fun = cubic_132) + stat_function(dat = subset(df2, stream_temp == 5.6), fun = cubic_5) + 
    stat_function(dat = subset(df2, stream_temp == 8.1), fun = cubic_8) + stat_function(dat = subset(df2, stream_temp == 9.6), fun = cubic_9) + 
    stat_function(dat = subset(df2, stream_temp == 13.9), fun = cubic_139) + stat_function(dat = subset(df2, stream_temp == 14.4), fun = cubic_14) + 
    stat_function(dat = subset(df2, stream_temp == 19.3), fun = cubic_193) + ylab(expression(paste("Mean Corrected Oxygen Consumption (",mu,"m/h)"))) + 
    xlab(expression(paste("Experimental Temperature (", ~degree ~C,")"))) + theme(legend.title = element_text(face="bold"))+
    scale_color_continuous(name=(expression(paste("Acclimation Temperature (", ~degree ~C,")")))) +
    geom_text(aes(x, y, label=legends, group=NULL), size = 2, data=legend)#, parse = T)

    
resp_full_plot2 
    
ggsave("../Results/cubic_plots.eps")
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
feed_full_plot = ggplot(df, aes(x =  exp_temp, y = log_mass_feed, color = stream_temp_fact)) + geom_point()  + 
     stat_smooth(dat = subset(df, stream_temp == 9.6), method = "lm", se = FALSE) +
    stat_smooth(dat = subset(df, stream_temp == 14.4), method = "lm", se = FALSE) +
    stat_smooth(dat = subset(df, stream_temp == 19.3), method = "lm", se = FALSE) +
   ylab(expression(paste("Ln Mean Corrected Feeding rate (mg ",m^-2," ", hr^-1,")"))) + 
    xlab(expression(paste("Experimental Temperature (", ~degree ~C,")"))) + theme(legend.title = element_text(face="bold"))+
    scale_color_discrete(name=(expression(paste("Acclimation Temperature (", ~degree ~C,")"))))
feed_full_plot

df$stream_temp_fact = factor(df$stream_temp_fact, labels = c("cold","tepid","warm"))
#levels(df$stream_temp_fact)
#feeding_model = lm(log_mass_feed~exp_temp, data = df)
#feeding_model
#anova(feeding_model)
acc_on_feed_model = lm(log_mass_feed~exp_temp*stream_temp_fact, data = df)
anova(acc_on_feed_model)
ggsave("../Results/meancorrectedfeeding_vs_exp_acctemp.eps")
# Out:
#                           Df Sum Sq    Mean Sq    F value   Pr(>F)
# exp_temp                   1 11.285716 11.2857165 21.936617 1.088074e-05
# stream_temp_fact           2  1.404931  0.7024653  1.365417 2.609476e-01
# exp_temp:stream_temp_fact  2  2.066850  1.0334250  2.008720 1.406304e-01
# Residuals                 83 42.700953  0.5144693        NA           NA
# Saving 6.67 x 6.67 in image
# plot without title

# %%
ener_full_plot = ggplot(df, aes(x =  exp_temp, y = En_Eff, color = stream_temp_fact)) + geom_point(shape=1) + facet_wrap(~stream_temp, ncol = 1) + 
                stat_smooth(method = "lm", se = FALSE) + ylab(expression(paste("Energetic Efficiency (",gamma,")"))) + 
    xlab(expression(paste("Experimental Temperature (", ~degree ~C,")"))) + theme(legend.title = element_text(face="bold"))+
    scale_color_discrete(name=(expression(paste("Acclimation Temperature (", ~degree ~C,")")))) 
ener_full_plot
ggsave("../Results/eneff_vs_accexptemp.eps")
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
model_feed = lm(En_Eff~exp_temp, data = df)
summary(model_feed)
# Out:
# Call:
# lm(formula = En_Eff ~ exp_temp, data = df)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.055446 -0.006623 -0.000001  0.005967  0.068359
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.0734711  0.0051306  14.320  < 2e-16 ***
# exp_temp    -0.0024326  0.0002682  -9.069 3.24e-14 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.01929 on 87 degrees of freedom
# Multiple R-squared:  0.486,	Adjusted R-squared:  0.4801
# F-statistic: 82.25 on 1 and 87 DF,  p-value: 3.242e-14

# %%
#boxplot(df$En_Eff~df$exp_temp)


EnExp_full_plot = ggplot(df, aes(x =  exp_temp, y = En_Eff, colour = exp_temp)) + geom_boxplot(aes(group = exp_temp)) + 
     ylab(expression(paste("Energetic Efficiency(",gamma,")"))) + 
    xlab(expression(paste("Experimental Temperature (", ~degree ~C,")"))) + theme(legend.title = element_text(face="bold"))+
    scale_color_continuous(name=(expression(paste("Experimental Temperature (", ~degree ~C,")")))) + theme(legend.position="none")
EnExp_full_plot

anova(model_feed)
ggsave("../Results/eneff_vs_exptemp.eps")
# Out:
#           Df Sum Sq     Mean Sq      F value  Pr(>F)
# exp_temp   1 0.03061763 0.0306176269 82.24924 3.241786e-14
# Residuals 87 0.03238612 0.0003722542       NA           NA
# Saving 6.67 x 6.67 in image
# plot without title

# %%
model_acc = lm(Log_Eneff_Mass~stream_temp_fact*exp_temp, data = df)
model_acc
# Out:
# Call:
# lm(formula = Log_Eneff_Mass ~ stream_temp_fact * exp_temp, data = df)
#
# Coefficients:
#                    (Intercept)           stream_temp_facttepid
#                        7.76548                        -1.02221
#           stream_temp_factwarm                        exp_temp
#                        1.21082                        -0.08046
# stream_temp_facttepid:exp_temp   stream_temp_factwarm:exp_temp
#                        0.03406                        -0.02424

# %%
#boxplot(Log_Eneff_Mass~stream_temp, data = df)

Log_massen_full_plot = ggplot(df, aes(x =  stream_temp, y = Log_Eneff_Mass, colour = stream_temp_fact)) + geom_boxplot(aes(group = stream_temp)) + 
     ylab(expression(paste("Ln Mean Corrected Energetic Efficiency(",gamma,")"))) + 
    xlab(expression(paste("Acclimation Temperature (", ~degree ~C,")"))) + theme(legend.title = element_text(face="bold"))+
    scale_color_discrete(name=(expression(paste("Acclimation Temperature (", ~degree ~C,")")))) + theme(legend.position="none")
Log_massen_full_plot

ggsave("../Results/meancorrectedeneff_vs_acctemp.eps")
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
anova(model_acc)
# Out:
#                           Df Sum Sq    Mean Sq   F value    Pr(>F)
# stream_temp_fact           2  23.27092 11.635462  5.6714392 0.0049126096
# exp_temp                   1  29.97467 29.974673 14.6104678 0.0002545616
# stream_temp_fact:exp_temp  2   3.21100  1.605500  0.7825642 0.4605760731
# Residuals                 83 170.28188  2.051589         NA           NA

# %%
model_accen_mass = lm(Log_Eneff_Mass~stream_temp_fact*exp_temp, data = df)

summary(model_accen_mass)

model_accen = lm(Log_Eneff~stream_temp_fact*exp_temp, data = df)

anova(model_accen)
# Out:
# Call:
# lm(formula = Log_Eneff_Mass ~ stream_temp_fact * exp_temp, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.2077 -0.9307 -0.0950  1.1254  3.1942
#
# Coefficients:
#                                Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     7.76548    0.75571  10.276   <2e-16 ***
# stream_temp_facttepid          -1.02221    0.97180  -1.052   0.2959
# stream_temp_factwarm            1.21082    0.98871   1.225   0.2242
# exp_temp                       -0.08046    0.03833  -2.099   0.0388 *
# stream_temp_facttepid:exp_temp  0.03406    0.05039   0.676   0.5010
# stream_temp_factwarm:exp_temp  -0.02424    0.05092  -0.476   0.6353
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.432 on 83 degrees of freedom
# Multiple R-squared:  0.249,	Adjusted R-squared:  0.2038
# F-statistic: 5.504 on 5 and 83 DF,  p-value: 0.0002002
#                           Df Sum Sq     Mean Sq    F value    Pr(>F)
# stream_temp_fact           2  0.2456592  0.1228296  0.2707444 7.634825e-01
# exp_temp                   1 31.2014019 31.2014019 68.7750025 1.694111e-12
# stream_temp_fact:exp_temp  2  1.7012381  0.8506191  1.8749583 1.597992e-01
# Residuals                 83 37.6549075  0.4536736         NA           NA

# %%
   
par(mfrow=c(1,2))

ggplot(df, aes(x =  exp_temp, y = Log_Eneff_Mass, colour = stream_temp_fact)) + geom_point() + 
    stat_smooth(dat = subset(df, stream_temp == 9.6), method = "lm", se = FALSE) +
    stat_smooth(dat = subset(df, stream_temp == 14.4), method = "lm", se = FALSE) +
    stat_smooth(dat = subset(df, stream_temp == 19.3), method = "lm", se = FALSE) +
     ylab(expression(paste("Ln Mean Corrected Energetic Efficiency(",gamma,")"))) + 
    xlab(expression(paste("Experimental Temperature (", ~degree ~C,")"))) + theme(legend.title = element_text(face="bold"))+
    scale_color_discrete(name=(expression(paste("Acclimation Temperature (", ~degree ~C,")"))))

ggsave("../Results/meancorrectedeneff_vs_expacctemp.eps")
ggplot(df, aes(x =  exp_temp, y = Log_Eneff, colour = stream_temp_fact)) + geom_point() + 
    stat_smooth(dat = subset(df, stream_temp == 9.6), method = "lm", se = FALSE) +
    stat_smooth(dat = subset(df, stream_temp == 14.4), method = "lm", se = FALSE) +
    stat_smooth(dat = subset(df, stream_temp == 19.3), method = "lm", se = FALSE) +
     ylab(expression(paste("Ln Energetic Efficiency"))) + 
    xlab(expression(paste("Experimental Temperature (", ~degree ~C,")"))) + theme(legend.title = element_text(face="bold"))+
    scale_color_discrete(name=(expression(paste("Acclimation Temperature (", ~degree ~C,")"))))

ggsave("../Results/lneneff_vs_expacctemp.eps")

anova(model_accen_mass)
anova(model_accen)
# Out:
# Saving 6.67 x 6.67 in image
# plot without title
# Saving 6.67 x 6.67 in image
#                           Df Sum Sq    Mean Sq   F value    Pr(>F)
# stream_temp_fact           2  23.27092 11.635462  5.6714392 0.0049126096
# exp_temp                   1  29.97467 29.974673 14.6104678 0.0002545616
# stream_temp_fact:exp_temp  2   3.21100  1.605500  0.7825642 0.4605760731
# Residuals                 83 170.28188  2.051589         NA           NA
#                           Df Sum Sq     Mean Sq    F value    Pr(>F)
# stream_temp_fact           2  0.2456592  0.1228296  0.2707444 7.634825e-01
# exp_temp                   1 31.2014019 31.2014019 68.7750025 1.694111e-12
# stream_temp_fact:exp_temp  2  1.7012381  0.8506191  1.8749583 1.597992e-01
# Residuals                 83 37.6549075  0.4536736         NA           NA
# plot without title
