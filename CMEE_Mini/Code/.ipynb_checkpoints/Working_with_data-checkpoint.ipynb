# %% [markdown]
# **Table of Contents**
# <div id="toc"></div>

# %% [markdown]
# # Importing DF

# %%
from scipy.constants import physical_constants as phy
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import math
from scipy import stats
import scipy.constants as sc
from lmfit import minimize, Minimizer, Parameters, Parameter, report_fit, fit_report
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_predict
import statsmodels.formula.api as sm
import seaborn as sns
sns.set(color_codes = True)
np.random.seed(1974)
ev = phy["joule-electron volt relationship"]
bolts = phy["Boltzmann constant in eV/K"]
k = bolts[0]
# Let printing work the same in Python 2 and 3
from __future__ import print_function

# %%
df1 = pd.read_csv('../Data/snail_respiration_BK.csv', sep =',')

# %%
df1.head()
# Out:
#    trial system date_time  year         species  stream  stream_temp  \
# 0     73    old  7.6_1300  2016  Radix balthica      11          5.6
# 1     74    old  7.6_1400  2016  Radix balthica      11          5.6
# 2     73    old  7.6_1300  2016  Radix balthica      11          5.6
# 3     74    old  7.6_1400  2016  Radix balthica      11          5.6
# 4     73    old  7.6_1300  2016  Radix balthica      11          5.6
#
#    exp_temp  chamber       mass      resp start_status end_status  \
# 0         5        3   3.014683  0.010438          NaN        NaN
# 1         5        3   3.014683  0.016002          NaN        NaN
# 2         5        4  11.716683  0.039203          NaN        NaN
# 3         5        4  11.716683  0.042461          NaN        NaN
# 4         5        5  13.338753  0.042687          NaN        NaN
#
#                                               comm_1 comm_2  comm_3  \
# 0                                                NaN    NaN     NaN
# 1  repeat of trial: 5 acute 7.6_1300_old, with re...    NaN     NaN
# 2                                                NaN    NaN     NaN
# 3  repeat of trial: 5 acute 7.6_1300_old, with re...    NaN     NaN
# 4                                                NaN    NaN     NaN
#
#    confidence_id outlier remove
# 0            NaN     NaN    NaN
# 1            NaN     NaN    NaN
# 2            NaN     NaN    NaN
# 3            NaN     NaN    NaN
# 4            NaN     NaN    NaN

# %%
df1["stream_temp"] = df1["stream_temp"].astype(str)

# %%
new_df = df1[["stream", "stream_temp", "exp_temp", "mass","resp"]]

# %%
new_df.head()
# Out:
#    stream stream_temp  exp_temp       mass      resp
# 0      11         5.6         5   3.014683  0.010438
# 1      11         5.6         5   3.014683  0.016002
# 2      11         5.6         5  11.716683  0.039203
# 3      11         5.6         5  11.716683  0.042461
# 4      11         5.6         5  13.338753  0.042687

# %%
stream_11 = new_df[(new_df["stream"] == 11)]

# %%
stream_11
# Out:
# {'13.2', '13.9', '14.4', '19.3', '5.6', '8.1', '9.6'}

# %%
plt.scatter("mass", "resp", data=stream_11)

# %%
groups = df1.groupby(["stream_temp","exp_temp"])

# %%
groups.head()
groups["exp_temp"].unique()
g = df1[(df1["exp_temp"] == 5)]

plt.scatter(g["mass"], g["resp"], marker = "x")
plt.show()

# %% [markdown]
# ## Getting the hang of the data

# %%
groups_s = stream_11.groupby(["stream_temp","exp_temp"])


# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups_s:
    ax.scatter(group["mass"], group["resp"], marker='x', label = name)
    ax.legend()

plt.title('Stream 11')
plt.ylabel('Respiration rate/ micromoles of O2 per per hour ')
plt.xlabel('Dry mass in mg')
plt.show()

# %%
print((new_df["stream"]).unique())
new_df_group = new_df.groupby("stream_temp")
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for title, group in new_df_group:
    group.plot.scatter(x = "exp_temp", y = "resp", marker='x',  title = title)
    plt.ylabel('Respiration rate/ micromoles of O2 per per hour ')
    plt.xlabel('Temperature')
    plt.show()
# Out:
# [11 12  2  5  6  8  9]

# %%
#fig.set_size_inches(18.5, 10.5)
#fig.savefig('../Results/stream_11.png', dpi=100)

# %% [markdown]
# ## Adding new columns to df

# %%
# y = t - t0/ k t t0   t0 normally mean of t approx
workingdf = new_df.assign(Exp_Temp_K = new_df["exp_temp"] + 273.15)
workingdf = workingdf.assign(log_resp = lambda x: np.log((x.resp)))
workingdf = workingdf.assign(mass_g = lambda x: x["mass"]/1000)
workingdf = workingdf.assign(x1 = lambda x: ((x["Exp_Temp_K"] - 290.65)/(k*x["Exp_Temp_K"]*290.65)))
workingdf = workingdf.assign(x2 = lambda x: (1/(k * x["Exp_Temp_K"]) ))
workingdf = workingdf.assign(log_mass_resp = lambda x: np.log(x["resp"] * (x["mass_g"]**(-3./4))))
workingdf = workingdf.assign(lnmass = lambda x: np.log(x["mass_g"]))
workingdf = workingdf.assign(mass_resp = lambda x: x["resp"] * (x["mass_g"]**(-3./4)))
workingdf = workingdf.dropna()
new_df = workingdf
workingdf = workingdf[(workingdf["exp_temp"] <= 30)]

M = workingdf["mass_g"]
T = workingdf["Exp_Temp_K"] 
b = 0.75
power = (k * T)
#workingdf = workingdf.loc[(workingdf["exp_temp"] < 31) & (workingdf["exp_temp"] > 9)]
new_df
# Out:
#      stream stream_temp  exp_temp       mass      resp  Exp_Temp_K  log_resp  \
# 0        11         5.6         5   3.014683  0.010438      278.15 -4.562267
# 1        11         5.6         5   3.014683  0.016002      278.15 -4.135015
# 2        11         5.6         5  11.716683  0.039203      278.15 -3.239007
# 3        11         5.6         5  11.716683  0.042461      278.15 -3.159176
# 4        11         5.6         5  13.338753  0.042687      278.15 -3.153868
# 5        11         5.6         5  13.338753  0.076883      278.15 -2.565466
# 6        11         5.6         5  23.529307  0.366810      278.15 -1.002910
# 7        11         5.6        10  16.986706  0.198874      283.15 -1.615086
# 8        11         5.6        10  21.959874  0.143871      283.15 -1.938837
# 9        11         5.6        10  29.566405  0.227699      283.15 -1.479730
# 10       11         5.6        10  29.566405  0.231053      283.15 -1.465110
# 11       11         5.6        10  33.709745  0.459715      283.15 -0.777148
# 12       11         5.6        15  12.783466  0.154576      288.15 -1.867068
# 13       11         5.6        15  12.783466  0.165231      288.15 -1.800411
# 14       11         5.6        15  29.566405  0.502737      288.15 -0.687689
# 15       11         5.6        15  45.537347  0.068588      288.15 -2.679641
# 16       11         5.6        15  55.871631  0.968795      288.15 -0.031703
# 17       11         5.6        20   1.857024  0.044811      293.15 -3.105302
# 18       11         5.6        20  16.986706  0.365704      293.15 -1.005932
# 19       11         5.6        20  19.730960  0.563655      293.15 -0.573313
# 20       11         5.6        20  21.200350  0.556025      293.15 -0.586941
# 517  0.010224  2.868713  37.057391       2.726770 -4.583054  15.283437
# 518  0.011717  2.868713  37.057391       2.379655 -4.446742  10.801174
# 519  0.013283  2.868713  37.057391       2.484629 -4.321303  11.996664
# 520  0.015094  2.868713  37.057391       2.527199 -4.193455  12.518388
# 521  0.015585  2.868713  37.057391       1.302096 -4.161436   3.676996
# 522  0.011255  3.451101  36.475003       1.865458 -4.486906   6.458896
# 523  0.011665  3.451101  36.475003       2.122426 -4.451174   8.351375
# 524  0.012674  3.451101  36.475003       1.859102 -4.368189   6.417971
# 525  0.013115  3.451101  36.475003       1.919518 -4.334009   6.817673
# 526  0.014792  3.451101  36.475003       1.817728 -4.213664   6.157854
# 527  0.016277  3.451101  36.475003       1.635647 -4.118031   5.132779
# 528  0.016921  3.451101  36.475003       1.699783 -4.079178   5.472758
#
# [529 rows x 13 columns]

# %% [markdown]
# ## Visualising the data

# %%
grouped_stream = new_df.groupby("stream_temp")

# Plot

for name, group in grouped_stream:
    plt.scatter("exp_temp", "resp", data=group,  marker='x', label = name)
    plt.legend()
    plt.show()

# %%
plt.scatter("x1", "log_resp", data=workingdf,  marker='x',  label = name)
plt.ylabel('Log Respiration rate')
plt.xlabel('t - t0/ k t t0')
plt.show()

# %%
plt.scatter("x2", "log_resp", data=workingdf,  marker='x',label = name)
plt.ylabel('Log Respiration rate')
plt.xlabel('1/ kT')
plt.show()

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Plotting linear regression on x1

# %%
#result = sm.ols(formula="A ~ B + C", data=df).fit()
data = np.matrix(np.asarray(workingdf))
regr = linear_model.LinearRegression()
x, y = data[:,8], data[:,6]
y1 = (workingdf["log_resp"]).values.reshape(-1,1)
x1 = (workingdf["x1"]).values.reshape(-1,1)

# %%
regr.fit(x1, y1)

x1_slope, x1_intercept, x1_r_value, x1_p_value, x1_std_err = stats.mstats.linregress(x1,y1)
print (x1_slope)
print (x1_intercept)
print (x1_r_value **  2)
# Out:
# 0.83520344795
# -1.81353122058
# 0.561343768574

# %%
print(regr.coef_, regr.intercept_)
# Out:
# [[ 0.83520345]] [-1.81353122]

# %%
predicted = cross_val_predict(regr, x1, y1, cv=10)

# %%
fig, ax = plt.subplots()
ax.scatter(y1, predicted, edgecolors=(0, 0, 0))
ax.plot([y1.min(), y1.max()], [y1.min(), y1.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()


# The coefficients
print('Coefficients: \n', regr.coef_[0,0])
#Intercept
print('Intercept: \n', regr.intercept_[0])
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y1, predicted))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y1, predicted))

x1_coef = regr.coef_[0,0]
x1_intercept = regr.intercept_[0]
# Out:
# Coefficients:
#  0.83520344795
# Intercept:
#  -1.81353122058
# Mean squared error: 0.84
# Variance score: 0.53

# %% [markdown]
# ## Training the model - didn't use, not sure it worked? Ask

# %%
# Split the data into training/testing sets
X_train = x1[:-20]
X_test = x1[-20:]

# Split the targets into training/testing sets
Y_train = y1[:-20]
Y_test = y1[-20:]

# Train the model using the training sets
regr.fit(X_train, Y_train)

# Make predictions using the testing set
Resp_Pred = regr.predict(X_test)

# The coefficients
print('Coefficients: \n', regr.coef_[0,0])
#Intercept
print('Intercept: \n', regr.intercept_[0])
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(Y_test, Resp_Pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(Y_test, Resp_Pred))

# Plot outputs
plt.scatter(X_test, Y_test,  color='black')
plt.plot(X_test, Resp_Pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  0.857296504988
# Intercept:
#  -1.79589378142
# Mean squared error: 0.66
# Variance score: -0.46

# %% [markdown]
# ## Plotting lm on plot

# %%
#sns.stripplot(x='x1', y='log_resp', data= workingdf, jitter=True) 
plt.scatter("x1", "log_resp", data=workingdf,  marker='x',  label = name)
plt.plot(x1, x1_intercept + x1*x1_coef, color='red')
plt.ylabel('Log Respiration rate')
plt.xlabel('t - t0/ k t t0')
plt.show()

# %%
p = sns.lmplot(x = "exp_temp", y = "log_resp", data= workingdf, x_jitter= 0.7)

# %% [markdown]
# ## On x2

# %%
x2 = (workingdf["x2"]).values.reshape(-1,1)

# %%
regr.fit(x2, y1)

x2_slope, x2_intercept1, x2_r_value, x2_p_value, x2_std_err = stats.mstats.linregress(x2,y1)
print (x2_slope)
print (x2_intercept1)
print (x2_r_value **  2)
# Out:
# -0.83520344795
# 31.5328884543
# 0.561343768574

# %%
predicted = cross_val_predict(regr, x2, y1, cv=10)

# %%
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y1.min(), y1.max()], [y1.min(), y1.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()


# The coefficients
print('Coefficients: \n', regr.coef_[0,0])
#Intercept
print('Intercept: \n', regr.intercept_[0])
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y1, predicted))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y1, predicted))

x2_coef = regr.coef_[0,0]
x2_intercept = regr.intercept_[0]
# Out:
# Coefficients:
#  -0.83520344795
# Intercept:
#  31.5328884543
# Mean squared error: 0.84
# Variance score: 0.53

# %%
#sns.stripplot(x='x1', y='log_resp', data= workingdf, jitter=True) 
plt.scatter("x2", "log_resp", data=workingdf,  marker='x',  label = name)
plt.plot(x2, x2_intercept + x2*x2_coef, color='red')
plt.ylabel('Log Respiration rate')
plt.xlabel('1/kt')
plt.show()

# %% [markdown]
# # Incorporating mass

# %% [markdown]
# ln(resp * mass ^ -3/4) = ln(B0) - E (1/kT)

# %%
y2 = workingdf["log_mass_resp"].values.reshape(-1,1)

# %%
regr.fit(x2, y2)
mass_resp_slope, mass_resp_intercept_lr, mass_resp_r_value, mass_resp_p_value, mass_resp_std_err = stats.mstats.linregress(x2,y2)
print (mass_resp_slope)
print (mass_resp_intercept_lr)
print (mass_resp_r_value **  2)
# Out:
# -0.799771869143
# 33.6746506095
# 0.739802060674

# %%
predicted = cross_val_predict(regr, x2, y2, cv=10)

# %%
fig, ax = plt.subplots()
ax.scatter(y2, predicted, edgecolors=(0, 0, 0))
ax.plot([y2.min(), y2.max()], [y2.min(), y2.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()

# The coefficients
print('Coefficients: \n', regr.coef_[0])
#Intercept
print('Intercept: \n', regr.intercept_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y2, predicted))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y2, predicted))

mass_resp_coef = regr.coef_[0]
mass_resp_intercept = regr.intercept_
# Out:
# Coefficients:
#  [-0.79977187]
# Intercept:
#  [ 33.67465061]
# Mean squared error: 0.33
# Variance score: 0.73

# %%
plt.scatter("x2", "log_mass_resp", data=workingdf,  marker='x',  label = name)
plt.plot(x2, mass_resp_intercept + (x2*mass_resp_coef), color='red')
plt.ylabel('Log (Mass ^3/4 * Respiration rate)')
plt.xlabel('1 / kT')
plt.show()

# %%
intercept_mass_resp_0C = mass_resp_intercept + mass_resp_coef*(1/(k*273.15))
mass_resp_at_10 = mass_resp_coef*(1/(k*283.15)) + mass_resp_intercept
mass_coef_in_C = (mass_resp_at_10 - intercept_mass_resp_0C) / 10
print(intercept_mass_resp_0C, mass_resp_at_10, mass_coef_in_C)
print ("The coefficient of this line is:\n",mass_coef_in_C[0],"\nand the intercept is: \n",intercept_mass_resp_0C[0])
# Out:
# [-0.30290875] [ 0.89707569] [ 0.11999844]
# The coefficient of this line is:
#  0.119998443789
# and the intercept is:
#  -0.302908749283

# %% [markdown]
# # ln(mass) by ln(I e ^ (E/kt))

# %%
workingdf = workingdf.assign(lnIEkt = lambda x: np.log((x.resp) * np.exp(mass_resp_coef/(k *workingdf["Exp_Temp_K"]))))
data = np.matrix(np.asarray(workingdf))
lnm, lnE = workingdf["lnmass"].values.reshape(-1,1) , workingdf["lnIEkt"].values.reshape(-1,1)
workingdf
# Out:
#      stream stream_temp  exp_temp       mass      resp  Exp_Temp_K  log_resp  \
# 0        11         5.6         5   3.014683  0.010438      278.15 -4.562267
# 1        11         5.6         5   3.014683  0.016002      278.15 -4.135015
# 2        11         5.6         5  11.716683  0.039203      278.15 -3.239007
# 3        11         5.6         5  11.716683  0.042461      278.15 -3.159176
# 4        11         5.6         5  13.338753  0.042687      278.15 -3.153868
# 5        11         5.6         5  13.338753  0.076883      278.15 -2.565466
# 6        11         5.6         5  23.529307  0.366810      278.15 -1.002910
# 7        11         5.6        10  16.986706  0.198874      283.15 -1.615086
# 8        11         5.6        10  21.959874  0.143871      283.15 -1.938837
# 9        11         5.6        10  29.566405  0.227699      283.15 -1.479730
# 10       11         5.6        10  29.566405  0.231053      283.15 -1.465110
# 11       11         5.6        10  33.709745  0.459715      283.15 -0.777148
# 12       11         5.6        15  12.783466  0.154576      288.15 -1.867068
# 13       11         5.6        15  12.783466  0.165231      288.15 -1.800411
# 14       11         5.6        15  29.566405  0.502737      288.15 -0.687689
# 15       11         5.6        15  45.537347  0.068588      288.15 -2.679641
# 16       11         5.6        15  55.871631  0.968795      288.15 -0.031703
# 17       11         5.6        20   1.857024  0.044811      293.15 -3.105302
# 18       11         5.6        20  16.986706  0.365704      293.15 -1.005932
# 19       11         5.6        20  19.730960  0.563655      293.15 -0.573313
# 20       11         5.6        20  21.200350  0.556025      293.15 -0.586941
# 21       11         5.6        20  25.166879  0.620488      293.15 -0.477250
# 22       11         5.6        20  34.416539  0.090876      293.15 -2.398259
# 23       11         5.6        25   4.924184  0.350166      298.15 -1.049348
# 24       11         5.6        25   5.917513  0.308106      298.15 -1.177312
# 25       11         5.6        25   7.217396  0.333696      298.15 -1.097525
# 26       11         5.6        25  10.223631  0.476800      298.15 -0.740657
# 27       11         5.6        25  10.707242  0.375026      298.15 -0.980761
# 481  0.008010  1.646301  38.279802       2.547594 -4.827032  12.776327
# 482  0.009031  1.646301  38.279802       3.090648 -4.707125  21.991314
# 483  0.011978  1.646301  38.279802       3.081001 -4.424688  21.780188
# 484  0.014199  1.646301  38.279802       2.767160 -4.254549  15.913373
# 485  0.015094  1.646301  38.279802       2.811454 -4.193455  16.634084
# 486  0.016662  1.646301  38.279802       2.760690 -4.094652  15.810752
#
#         lnIEkt
# 0   -37.929049
# 1   -37.501797
# 2   -36.605788
# 3   -36.525958
# 4   -36.520650
# 5   -35.932248
# 6   -34.369692
# 7   -34.392661
# 8   -34.716412
# 9   -34.257305
# 10  -34.242685
# 11  -33.554723
# 12  -34.075884
# 13  -34.009227
# 14  -32.896505
# 15  -34.888457
# 16  -32.240519
# 17  -34.764760
# 18  -32.665391
# 19  -32.232772
# 20  -32.246400
# 21  -32.136708
# 22  -34.057718
# 23  -32.177875
# 24  -32.305839
# 25  -32.226052
# 26  -31.869184
# 27  -32.109288
# 28  -31.718187
# 29  -31.666850
# ..         ...
# 457 -33.194780
# 458 -32.181971
# 459 -33.517266
# 460 -32.577313
# 461 -33.567309
# 462 -33.534988
# 463 -33.160017
# 464 -33.859821
# 465 -33.097325
# 466 -32.810599
# 467 -32.594388
# 468 -32.402515
# 469 -32.102744
# 470 -31.825055
# 471 -32.259758
# 472 -31.366196
# 473 -32.583817
# 474 -31.463433
# 475 -33.155451
# 476 -32.788060
# 477 -32.661822
# 478 -31.147672
# 479 -31.640050
# 480 -31.176478
# 481 -31.687789
# 482 -31.054805
# 483 -30.852624
# 484 -31.038861
# 485 -30.948746
# 486 -30.925408
#
# [336 rows x 14 columns]

# %%
regr.fit(lnm, lnE)
lnm_slope, lnm_intercept, lnm_r_value, lnm_p_value, lnm_std_err = stats.mstats.linregress(lnm, lnE)
print (lnm_slope)
print (lnm_intercept)
print (lnm_r_value **  2)
# Out:
# 0.923801757289
# -29.0974978072
# 0.140043100068

# %%
predicted = cross_val_predict(regr, lnm, lnE, cv=10)

fig, ax = plt.subplots()
ax.scatter(lnE, predicted, edgecolors=(0, 0, 0))
ax.plot([lnE.min(), lnE.max()], [lnE.min(), lnE.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()


# The coefficients
print('Coefficients: \n', regr.coef_[0,0])
#Intercept
print('Intercept: \n', regr.intercept_[0])
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(lnE, predicted))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(lnE, predicted))

lnm_coef = regr.coef_[0,0]
lnm_intercept = regr.intercept_[0]
# Out:
# Coefficients:
#  0.923801757289
# Intercept:
#  -29.0974978072
# Mean squared error: 4.26
# Variance score: 0.07

# %%
plt.scatter("lnmass", "lnIEkt", data=workingdf,  marker='x',  label = name)
plt.plot(lnm, lnm_intercept + lnm*lnm_slope, color='red')
plt.ylabel('Ln(IeEkt)')
plt.xlabel('ln(mass)')
plt.show()

# %% [markdown]
# ## plotting x2 linear model

# %%
intercept_x2_0C = x2_intercept + x2_coef*(1/(k*273.15))
resp_at_10 = x2_coef*(1/(k*283.15)) + x2_intercept
coef_in_C = (resp_at_10 - intercept_x2_0C) / 10
print(intercept_x2_0C, resp_at_10, coef_in_C)
print ("The coefficient of this line is:\n",coef_in_C,"\nand the intercept is: \n",intercept_x2_0C)

plt.scatter("exp_temp", "log_resp", data=workingdf,  marker='x',  label = name)
plt.plot(workingdf["exp_temp"], intercept_x2_0C + workingdf["exp_temp"]*coef_in_C, color='red')
plt.ylabel('Log Respiration rate')
plt.xlabel('Temp in degrees C')
plt.show()
# Out:
# -3.9499483698 -2.69680209313 0.125314627668
# The coefficient of this line is:
#  0.125314627668
# and the intercept is:
#  -3.9499483698

# %%
print ("1/kt r^2 value is: \n", (x2_r_value)**2)
print ("Tt - T0/kTtT0 r^2 value is: \n", (x1_r_value)**2)
print ("Including mass in 1/kt, r^2 is: \n", (mass_resp_r_value)**2, "\nand finally, the ln(mass) r^2 value is: \n", lnm_r_value**2)
# Out:
# 1/kt r^2 value is:
#  0.561343768574
# Tt - T0/kTtT0 r^2 value is:
#  0.561343768574
# Including mass in 1/kt, r^2 is:
#  0.739802060674
# and finally, the ln(mass) r^2 value is:
#  0.140043100068

# %%
kt = workingdf["lnmass"].values.reshape(-1,1)

regr.fit(kt, y)

kt_slope, kt_intercept1, kt_r_value, kt_p_value, kt_std_err = stats.mstats.linregress(kt,y)
print (kt_slope)
print (kt_intercept1)
print (kt_r_value **  2)
# Out:
# 0.8522580284477265
# 2.36127625829
# 0.308681317239

# %%
B0 = resp_at_10
B0
mass_resp_coef
# Out:
# array([-0.79977187])

# %%
set(new_df["stream"])
# Out:
# {2, 5, 6, 8, 9, 11, 12}

# %%
# Plot

for name, group in grouped_stream:
    plt.scatter("exp_temp", "resp", data=group,  marker='x', label = name)
    plt.legend()
    plt.show()

# %%
intercept_mass_resp_0C = mass_resp_intercept + mass_resp_coef*(1/(k*273.15))
mass_resp_at_10 = mass_resp_coef*(1/(k*283.15)) + mass_resp_intercept
mr_coef_in_C = (mass_resp_at_10 - intercept_mass_resp_0C) / 10
print(intercept_mass_resp_0C, mass_resp_at_10, mr_coef_in_C)
print ("The coefficient of this line is:\n",mr_coef_in_C[0],"\nand the intercept is: \n",intercept_mass_resp_0C[0])

plt.scatter("exp_temp", "log_mass_resp", data=workingdf,  marker='x',  label = name)
plt.plot(workingdf["exp_temp"], intercept_mass_resp_0C + workingdf["exp_temp"]*mr_coef_in_C, color='red')
plt.ylabel('Log Mass_Respiration rate')
plt.xlabel('Temp in degrees C')
plt.show()

mr_B0 = np.exp(mass_resp_at_10)[0]
print(mass_resp_r_value**2)
# Out:
# [-0.30290875] [ 0.89707569] [ 0.11999844]
# The coefficient of this line is:
#  0.119998443789
# and the intercept is:
#  -0.302908749283
# 0.739802060674

# %%
grouped_mr = new_df.groupby("stream_temp")
# Plot

for name, group in grouped_mr:
    plt.scatter("exp_temp", "mass_resp", data=group,  marker='x', label = name)
    plt.legend()
    plt.show()

plt.scatter(new_df["exp_temp"], new_df["mass_resp"])
# Out:
# array([ 33.67465061])

# %%
mr_B0 = np.exp(mass_resp_at_10)[0]
lenx = len(new_df["Exp_Temp_K"])
x = np.linspace(new_df["Exp_Temp_K"].min(),new_df["Exp_Temp_K"].max(),lenx)
params = Parameters()
Temp_H_K = 306.15
Temp_L_K = 278.15
Eh = mass_resp_coef[0]
data = new_df["mass_resp"].values
#x = new_df["Exp_Temp_K"].values



params.add_many(("mass_resp_coef", -(mass_resp_slope),  True, 0.3, 0.9),
               ("mass_resp_at_10", mr_B0, True, 1, 7),
               ("Eh", Eh, True, -1.5, 1.8),
               ("Temp_H_K", Temp_H_K, True, 300, 308),
               ("Temp_L_K", Temp_L_K, True, 273, 283),
               ("boltz", k, False),
               ("El", 0.3, True, -2.0, 2.0),
               ("mass_resp_intercept", mass_resp_intercept_lr, True, 30, 35))
#print(params)

def lnIM34(params, x, workingdf = None):
    E = params["mass_resp_coef"]
    B0 = params["mass_resp_intercept"]
    K = params["boltz"]
    
    model = B0 - E*x #+ E*(1/(K*283.15))
    
    if workingdf is None:
        return model
    
    return model - workingdf



def trait(params, x, workingdf = None):
    E = params["mass_resp_coef"]
    B0 = params["mass_resp_at_10"]
    K = params["boltz"]
    exp = (1/x) - (1/283.15)
    
    model = B0 * np.exp((-E/K)*(exp))
    
    if workingdf is None:
        return model
    
    return model - workingdf




x_trait = np.linspace(workingdf["Exp_Temp_K"].min(),workingdf["Exp_Temp_K"].max(),len(workingdf["Exp_Temp_K"]))        

lenx2 = len(workingdf["x2"])
x2_for_lnIM34 = np.linspace(workingdf["x2"].min(), workingdf["x2"].max(), lenx2)
y_for_lnIM34 = workingdf["log_mass_resp"].values


result_lnIM34 = minimize(lnIM34, params, args=(x2_for_lnIM34,y_for_lnIM34))
result_trait = minimize(trait, params, args=(x_trait,y_for_lnIM34))


#result_lnIM34.params.pretty_print()
#result_trait.params.pretty_print()
#result.params["Eh"]


# calculate final result
final_trait = y_for_lnIM34 + result_trait.residual
finalx2 = y_for_lnIM34 + result_lnIM34.residual

# write error report
#report_fit(result_lnIM34.params, min_correl=0.5)
#report_fit(result_trait.params, min_correl=0.5)
print(fit_report(result_lnIM34))
print(fit_report(result_trait))


# plot the data
plt.plot(workingdf["x2"], workingdf["log_mass_resp"], 'b*')
#plt.plot(x, data, 'bo')
plt.plot(x2_for_lnIM34, finalx2, 'r')
#plt.plot(result_lnIM34.init_vals, "r-")
plt.show()



plt.scatter("x2", "log_mass_resp", data=workingdf,  marker='x',  label = name)
plt.plot(x2, mass_resp_intercept + (x2*mass_resp_coef), color='red')
plt.ylabel('Log (Mass ^3/4 * Respiration rate)')
plt.xlabel('1 / kT')
plt.show()

plt.plot(workingdf["Exp_Temp_K"], workingdf["log_mass_resp"], 'b*')
#plt.plot(x, data, 'bo')
plt.plot(x_trait, final_trait, 'r')
plt.show()
# Out:
# [[Fit Statistics]]
#     # function evals   = 100
#     # data points      = 336
#     # variables        = 7
#     chi-square         = 577.263
#     reduced chi-square = 1.755
# [[Variables]]
#     mass_resp_coef:        0.70263305 +/- 0        (0.00%) (init= 0.7997719)
#     mass_resp_at_10:       2.45242097 +/- 0        (0.00%) (init= 2.452421)
#     Eh:                   -0.79977186 +/- 0        (0.00%) (init=-0.7997719)
#     Temp_H_K:              306.150000 +/- 0        (0.00%) (init= 306.15)
#     Temp_L_K:              278.150000 +/- 0        (0.00%) (init= 278.15)
#     boltz:                 8.61733e-05 (fixed)
#     El:                    0.30000000 +/- 0        (0.00%) (init= 0.3)
#     mass_resp_intercept:   30.0000000 +/- 0        (0.00%) (init= 33.67465)
# [[Correlations]] (unreported correlations are <  0.100)
# [[Fit Statistics]]
#     # function evals   = 97
#     # data points      = 336
#     # variables        = 7
#     chi-square         = 505.552
#     reduced chi-square = 1.537
# [[Variables]]
#     mass_resp_coef:        0.30000000 +/- 0        (0.00%) (init= 0.7997719)
#     mass_resp_at_10:       1.21393193 +/- 0        (0.00%) (init= 2.452421)
#     Eh:                   -0.79977186 +/- 0        (0.00%) (init=-0.7997719)
#     Temp_H_K:              306.150000 +/- 0        (0.00%) (init= 306.15)
#     Temp_L_K:              278.150000 +/- 0        (0.00%) (init= 278.15)
#     boltz:                 8.61733e-05 (fixed)
#     El:                    0.30000000 +/- 0        (0.00%) (init= 0.3)
#     mass_resp_intercept:   33.6746506 +/- 0        (0.00%) (init= 33.67465)
# [[Correlations]] (unreported correlations are <  0.100)

# %%
# This is the log-likelihood probability for the sampling. We're going to estimate the
# size of the uncertainties on the data as well
def lnprob(p):
    resid = residual(p)
    s = p['f']
    resid *= 1 / s
    resid *= resid
    resid += np.log(2 * np.pi * s**2)
    
    return -0.5 * np.sum(resid)

# %%
def residual(params, x, workingdf = None):
    E = params["mass_resp_coef"]
    B0 = params["mass_resp_at_10"]
    Eh = params["Eh"]
    El = params["El"]
    Th = params["Temp_H_K"]
    Tl = params["Temp_L_K"]
    K = params["boltz"]
    exp1 = ((-E)/K) * (1/x - 1/283.15)
    #print(exp1)
    exp2 = (Eh/K) * (1/Th - 1/x)
    #print(exp2)
    exp3 = (El/K) * (1/Tl - 1/x)
    model = (B0 * np.exp(exp1))/(1 + np.exp(exp3) + np.exp(exp2))
    
    if workingdf is None:
        return model
    
    return model - workingdf


out = minimize(residual, params, args=(x, data))

# %%
out.params.pretty_print()
#out.params["Eh"]



# calculate final result
final = data + out.residual

# write error report
report_fit(out.params)

# plot the data
plt.plot(new_df["Exp_Temp_K"], data, 'bo')
#plt.plot(x, data, 'bo')
plt.plot(x, final, 'r')
plt.show()
# Out:
# Parameters({
#     'mass_resp_coef': <Parameter 'mass_resp_coef', value=0.89965382295501217 +/- 0, bounds=[0.3:0.9]>,
#     'mass_resp_at_10': <Parameter 'mass_resp_at_10', value=7.0 +/- 0, bounds=[1:7]>,
#     'Eh': <Parameter 'Eh', value=1.5667315820713235 +/- 0, bounds=[-1.5:1.8]>,
#     'Temp_H_K': <Parameter 'Temp_H_K', value=300.00000000000006 +/- 0, bounds=[300:308]>,
#     'Temp_L_K': <Parameter 'Temp_L_K', value=282.9999999196279 +/- 0, bounds=[273:283]>,
#     'boltz': <Parameter 'boltz', value=8.6173303e-05 (fixed), bounds=[None:None]>,
#     'El': <Parameter 'El', value=0.48962023003252986 +/- 0, bounds=[-2.0:2.0]>,
#     'mass_resp_intercept': <Parameter 'mass_resp_intercept', value=33.674650609464763 +/- 0, bounds=[30:35]>,
#     })
#
# [[Variables]]
#     mass_resp_coef:        0.89965382 +/- 0        (0.00%) (init= 0.7997719)
#     mass_resp_at_10:       7          +/- 0        (0.00%) (init= 2.452421)
#     Eh:                    1.56673158 +/- 0        (0.00%) (init=-0.7997719)
#     Temp_H_K:              300        +/- 0        (0.00%) (init= 306.15)
#     Temp_L_K:              282.999999 +/- 0        (0.00%) (init= 278.15)
#     boltz:                 8.61733e-05 (fixed)
#     El:                    0.48962023 +/- 0        (0.00%) (init= 0.3)
#     mass_resp_intercept:   33.6746506 +/- 0        (0.00%) (init= 33.67465)
# [[Correlations]] (unreported correlations are <  0.100)

# %%
#!/usr/bin/env python
#<examples/doc_withreport.py>

from __future__ import print_function
from lmfit import Parameters, minimize, fit_report
from numpy import random, linspace, pi, exp, sin, sign


p_true = Parameters()
p_true.add('amp', value=14.0)
p_true.add('period', value=5.46)
p_true.add('shift', value=0.123)
p_true.add('decay', value=0.032)

def residual(pars, x, data=None):
    vals = pars.valuesdict()
    amp =  vals['amp']
    per =  vals['period']
    shift = vals['shift']
    decay = vals['decay']

    if abs(shift) > pi/2:
        shift = shift - sign(shift)*pi
    model = amp * sin(shift + x/per) * exp(-x*x*decay*decay)
    if data is None:
        return model
    return (model - data)

n = 1001
xmin = 0.
xmax = 250.0

random.seed(0)

noise = random.normal(scale=0.7215, size=n)
#print(noise)
x     = linspace(xmin, xmax, n)
data  = residual(p_true, x) + noise

fit_params = Parameters()
fit_params.add('amp', value=13.0)
fit_params.add('period', value=2)
fit_params.add('shift', value=0.0)
fit_params.add('decay', value=0.02)

out = minimize(residual, fit_params, args=(x,), kws={'data':data})

print(fit_report(out))


#<end of examples/doc_withreport.py>
# Out:
# [[Fit Statistics]]
#     # function evals   = 85
#     # data points      = 1001
#     # variables        = 4
#     chi-square         = 498.812
#     reduced chi-square = 0.500
# [[Variables]]
#     amp:      13.9121944 +/- 0.141202 (1.01%) (init= 13)
#     period:   5.48507044 +/- 0.026664 (0.49%) (init= 2)
#     shift:    0.16203676 +/- 0.014056 (8.67%) (init= 0)
#     decay:    0.03264538 +/- 0.000380 (1.16%) (init= 0.02)
# [[Correlations]] (unreported correlations are <  0.100)
#     C(period, shift)             =  0.797
#     C(amp, decay)                =  0.582
#     C(amp, shift)                = -0.297
#     C(amp, period)               = -0.243
#     C(shift, decay)              = -0.182
#     C(period, decay)             = -0.150

# %%
analyse_newdf = new_df.groupby("stream_temp")
analyse_wdf = workingdf.groupby("stream_temp")

for name, group in analyse_newdf:
    group.plot.scatter("exp_temp", "resp", marker='x', title = name)
    plt.legend()
    plt.show()
# Out:
# /home/abi/.local/share/canopy/edm/envs/User/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
